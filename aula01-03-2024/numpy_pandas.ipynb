# %%
print ("hello world")
# Out:
# hello world

# %% [markdown]
# # Exploratory data analysis (EDA)
#
# Aprendizado de máquina consiste em treinar modelos a partir de dados. Antes de usar os dados, precisamos inspecionar a partir de dados. Antes de usar dados, precisamos inspecionar o que são: se eles seguem premissas, se tem dados faltantes, se são numéricos, se fazem sentido, etc.
#
# lembrando da máxima `sh*t in, sh*t out`
#
# A tarefa de EDA é usar estatisticas **descritivas** e gráficos para isso.
#
# ![texto alternativo](link da imagem)

# %%
# !pip install numpy
import numpy as np

# %%
np.median(lista)

# %%
#!pip install pandas

import pandas as pd

# %%
df = pd.read_csv("passwords.csv")

# %%
df.dropna(inplace=True)
df.tail(8)
# Out:
#       rank  password          category  value time_unit  offline_crack_sec  \
# 492  493.0    chance              name   3.72      days            0.00321
# 493  494.0   genesis         nerdy-pop   3.19    months            0.08350
# 494  495.0    hotrod        cool-macho   3.72      days            0.00321
# 495  496.0    reddog        cool-macho   3.72      days            0.00321
# 496  497.0  alexande              name   6.91     years            2.17000
# 497  498.0   college         nerdy-pop   3.19    months            0.08350
# 498  499.0    jester              name   3.72      days            0.00321
# 499  500.0  passw0rd  password-related  92.27     years           29.02000
#
#      rank_alt  strength  font_size
# 492     495.0       7.0       11.0
# 493     496.0       7.0       11.0
# 494     497.0       7.0       11.0
# 495     498.0       6.0       10.0
# 496     499.0       9.0       12.0
# 497     500.0       7.0       11.0
# 498     501.0       7.0       11.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rank               500 non-null    float64
#  1   password           500 non-null    object
#  2   category           500 non-null    object
#  3   value              500 non-null    float64
#  4   time_unit          500 non-null    object
#  5   offline_crack_sec  500 non-null    float64
#  6   rank_alt           500 non-null    float64
#  7   strength           500 non-null    float64
#  8   font_size          500 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 39.1+ KB

# %%
df['offline_crack_sec']
# Out:
# 0      2.170000e+00
# 1      1.110000e-05
# 2      1.110000e-03
# 3      1.110000e-07
# 4      3.210000e-03
#            ...
# 495    3.210000e-03
# 496    2.170000e+00
# 497    8.350000e-02
# 498    3.210000e-03
# 499    2.902000e+01
# Name: offline_crack_sec, Length: 500, dtype: float64

# %%
np.mean(df["offline_crack_sec"])
# Out:
# 0.500009642982

# %%
df.describe()
# Out:
#              rank       value  offline_crack_sec    rank_alt    strength  \
# count  500.000000  500.000000       5.000000e+02  500.000000  500.000000
# mean   250.500000    5.602660       5.000096e-01  251.224000    7.432000
# std    144.481833    8.436005       2.658132e+00  145.052163    5.415536
# min      1.000000    1.290000       1.110000e-07    1.000000    0.000000
# 25%    125.750000    3.430000       3.210000e-03  125.750000    6.000000
# 50%    250.500000    3.720000       3.210000e-03  251.500000    7.000000
# 75%    375.250000    3.720000       8.350000e-02  376.250000    8.000000
# max    500.000000   92.270000       2.927000e+01  502.000000   48.000000
#
#         font_size
# count  500.000000
# mean    10.298000
# std      3.651282
# min      0.000000
# 25%     10.000000
# 50%     11.000000
# 75%     11.000000
# max     28.000000

# %% [markdown]
# # Pipeline de ML
#
# 1. instalar/importar bibliotecas
#     - (pandas, seaborn, matplotlib,numpy)
# 2. crregar dados tabulares
# 3. limpar/preencher dados faltantes
# 4. ver informações da coluna(`df.info()`)
# 5. ver estastísticas descritivas (`df.describe()`)
# 6. fazer gráficos (matplotlib, seaborn, pandas)
# 7. usar pairplot!
# 8. interpretar as estatísticas e gráficos
# 9. próximos capitulos...

# %%
# !pip install seaborn

import seaborn as sns

# %%
sns.pairplot(df)
